# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

# %%
# Load the environment variables from the .env file
load_dotenv()
# Out:
# True

# %%
# Initialize the OpenAI client (it automatically detects OPENAI_API_KEY from os.environ)
client = OpenAI()
